# %%
def do_calculation():
    import pandas as pd 
    import matplotlib.pyplot as plt
    df1 =pd.read_csv('https://api.covid19india.org/csv/latest/case_time_series.csv')
    columns=df1.columns
    from matplotlib.ticker import EngFormatter
    # %matplotlib notebook
    import datetime as dt
    import matplotlib.dates as mdate
    df1=df1[df1!='?'].dropna()
    df1['Active']=df1['Total Confirmed']-df1['Total Recovered']-df1['Total Deceased'] 
    df1.head()
    columns = df1.columns.drop(['Date_YMD','Total Confirmed','Total Recovered','Date'])
    y_data = range(0,119)
    fig, ax = plt.subplots()
    for column in columns:
        ax.plot(df1['Date'],df1[column],label=column)
    ax.set_title("PM2.5 a week Before & After Diwali (of 2019 and 2020) || Baghpat,Uttar Pradesh,India")
    #ax.set_xlabel('Date & Time')
    ax.set_ylabel('unit: ug/m³')
    ax.legend()
    plt.grid(color='black', linestyle='dotted', linewidth=0.1)
    #formatter0 = EngFormatter(unit='ug/m³')
    #ax.yaxis.set_major_formatter(formatter0)
    plt.xticks(rotation ='vertical') 
    plt.rc('xtick', labelsize=3)
    plt.show()
do_calculation()
# Out:
# C:\Users\arjun\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# <img src="data:image/png;base64,..." width="640">
