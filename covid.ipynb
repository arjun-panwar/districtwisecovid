# %%
import pandas as pd 
import matplotlib.pyplot as plt
df1 =pd.read_csv('downloads/covid_19_india.csv', index_col=['Sno'])
columns=df1.columns
from matplotlib.ticker import EngFormatter
# %matplotlib
import datetime as dt
import matplotlib.dates as mdate
df1['Active']=df1['Confirmed']-df1['Cured']-df1['Deaths']
# Out:
# Using matplotlib backend: Qt5Agg

# %%
dfg=df1[df1!='?'].dropna()
# Out:
# C:\Users\arjun\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
sg = dfg.groupby('State') 
state =gk.get_group('Delhi')
gk.first()
# Out:
#                                                 Date     Time    Cured  \
# State
# Andaman and Nicobar Islands               26-03-2020  6:00 PM        0
# Andhra Pradesh                            12-03-2020  6:00 PM        0
# Arunachal Pradesh                         03-04-2020  6:00 PM        0
# Assam                                     01-04-2020  7:30 PM        0
# Bihar                                     22-03-2020  6:00 PM        0
# Cases being reassigned to states          20-05-2020  8:00 AM        0
# Chandigarh                                19-03-2020  6:00 PM        0
# Chandigarh***                             15-11-2020  8:00 AM    14381
# Chhattisgarh                              19-03-2020  6:00 PM        0
# Dadar Nagar Haveli                        06-05-2020  8:00 AM        0
# Dadra and Nagar Haveli and Daman and Diu  12-06-2020  8:00 AM        2
# Daman & Diu                               11-06-2020  8:00 AM        0
# ...

# %%
df3 = state
columns = state.columns.drop(['Time','Date','Deaths'])
y_data = range(0,119)
fig, ax = plt.subplots()
for column in columns:
    ax.plot(df3['Date'],state[column],label=column)
ax.set_title("PM2.5 a week Before & After Diwali (of 2019 and 2020) || Baghpat,Uttar Pradesh,India")
#ax.set_xlabel('Date & Time')
ax.set_ylabel('unit: ug/m³')
ax.legend()
plt.grid(color='black', linestyle='dotted', linewidth=0.1)
#formatter0 = EngFormatter(unit='ug/m³')
#ax.yaxis.set_major_formatter(formatter0)
plt.xticks(rotation ='vertical') 
plt.rc('xtick', labelsize=3)
